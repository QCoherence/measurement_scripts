# %% [markdown]
# # Open a HDF5 file generator by Presto

# %%
import h5py
import matplotlib.pyplot as plt

# %%
filename = r"C:/Users/nicolas.roch/Measurements/Qubit/Presto/presto-measure/data/two_tone_pulsed_20221129_220514.h5"

# %%
file = h5py.File(filename)

# %%
file.keys()
# Out:
# <KeysViewHDF5 ['control_freq_arr', 'source_code', 'store_arr', 't_arr']>

# %%
plt.plot(file['store_arr'][...][3][0])
plt.show()

# %%
file['source_code'][...]
# Out:
# array([b'# -*- coding: utf-8 -*-\n', b'"""\n',
#        b'Two-tone spectroscopy with Pulsed mode: sweep of pump frequency, with fixed pump power and fixed probe.\n',
#        b'"""\n', b'import ast\n', b'\n', b'import h5py\n',
#        b'import numpy as np\n', b'\n',
#        b'from presto.hardware import AdcFSample, AdcMode, DacFSample, DacMode\n',
#        b'from presto import pulsed\n',
#        b'from presto.utils import rotate_opt, sin2\n', b'\n',
#        b'from _base import Base\n', b'\n',
#        b'DAC_CURRENT = 32_000  # uA\n', b'CONVERTER_CONFIGURATION = {\n',
#        b'    "adc_mode": AdcMode.Mixed,\n',
#        b'    "adc_fsample": AdcFSample.G4,\n',
#        b'    "dac_mode": [DacMode.Mixed42, DacMode.Mixed02, DacMode.Mixed02, DacMode.Mixed02],\n',
#        b'    "dac_fsample": [DacFSample.G10, DacFSample.G6, DacFSample.G6, DacFSample.G6],\n',
#        b'}\n', b'IDX_LOW = 2_00\n', b'IDX_HIGH = 4_00\n',
#        b'IDX_freq_plot = 0\n', b'\n', b'\n',
# ...
