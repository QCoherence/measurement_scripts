# %% [markdown]
# <h1 style="color:#2F659C";>Azog C1 measurement script</h1>
# This notebook can be used to start a new measurement. It includes all the imports and instrument initializations, which can then be removed according to the measurement necessities. A small description of the Chip can be added here, and it is a good practice to change the sample name accordingly.

# %%
sample_name = 'azog_c1'  # name of the chip in the fridge
user = 'ncr'             # who is performing measurements

# date = '20220203'        # when did the measurements started
# description = 'ramp_statistics_v1'   # super short description of what you are doing

date = '20220203'        # when did the measurements started
description = 'power_dependance_v1'   # super short description of what you are doing

# date = '20220201'        # when did the measurements started
# description = 'bloch_oscillations_v1'   # super short description of what you are doing

# date = '20220131'        # when did the measurements started
# description = 'chip_characterisation_v2'   # super short description of what you are doing

# date = '20220207'        # when did the measurements started
# description = 'current_bias_v1'   # super short description of what you are doing

# date = '20220203'        # when did the measurements started
# description = 'lock-in_v1'   # super short description of what you are doing

# %% [markdown]
# <h3 style="color:#418FDB";>QCodes imports</h3>
# Import the QCodes functions used in the measurement of this sample.

# %%
import os
import sys
from time import sleep, perf_counter
import json
import matplotlib.pyplot as plt
import numpy as np
import tqdm.notebook as tqdm
import qcodes as qc
import time
from qcodes import (
    Measurement,
    experiments,
    initialise_database,
    initialise_or_create_database_at,
    load_by_guid,
    load_by_run_spec,
    load_experiment,
    load_last_experiment,
    load_or_create_experiment,
    new_experiment,
    validators
)
from qcodes.instrument.parameter import Parameter

#from qcodes.utils.dataset.doNd import do0d, do1d, do2d, dond, plot, LinSweep, LogSweep

from qcodes.dataset.plotting import plot_dataset
from qcodes.logger.logger import start_all_logging, start_command_history_logger
from qcodes.tests.instrument_mocks import DummyInstrument, DummyInstrumentWithMeasurement
from qcodes.interactive_widget import experiments_widget

# %%
sys.path.append(r'C:\Users\nicolas.roch\Measurements\Scripts')

from QMETfunc.QMET_measurement import do0d, do1d, do2d, dond, LinSweep, LogSweep

# %% [markdown]
# <h2 style="color:#1C3C5C";>Station and database setup</h2>
# Add the instruments to the station and start all the loggings related to the measurement. Then create or initialise the database where all the data will be saved.

# %%
data_dir = os.path.join(r'D:\QMET' + '\\' + sample_name)

# %% [markdown]
# <h3 style="color:#418FDB";>Database initialization</h3>

# %%
database_name = date + '_' + user + '_' + description
try :
    os.mkdir(data_dir)
except FileExistsError:
    pass

qc.initialise_or_create_database_at(data_dir + '\\' + database_name + '.db')
qc.config.core.db_location
# Out:
# 'D:\\QMET\\azog_c1\\20220203_ncr_power_dependance_v1.db'

# %% [markdown]
# <h3 style="color:#418FDB";>Station initialization</h3>

# %%
STATION = qc.Station()

start_all_logging()
start_command_history_logger(data_dir)
# Out:
# Activating auto-logging. Current session state plus future input saved.
# Filename       : C:\Users\nicolas.roch\.qcodes\logs\command_history.log
# Mode           : append
# Output logging : True
# Raw input log  : False
# Timestamping   : True
# State          : active
# Qcodes Logfile : C:\Users\nicolas.roch\.qcodes\logs\220304-23776-qcodes.log
# Activating auto-logging. Current session state plus future input saved.
# Filename       : D:\QMET\azog_c1\command_history.log
# Mode           : append
# Output logging : True
# Raw input log  : False
# Timestamping   : True
# State          : active

# %% [markdown]
# <h3 style="color:#418FDB";>Instruments initialisation</h3>
# Add to path the folder containing the drivers. Then import and connect to the used instruments, while delete the unused ones.

# %%
sys.path.append(r'C:\Users\nicolas.roch\Measurements\Drivers')

# %% [markdown]
# <h4 style="color:#4697E8";>Connect to the ADwin</h4>

# %%
from ADwin_Gold2 import ADwin_Gold2, ADwin_ramp, ADwin_averagedRamp, ADwin_IV,  ADwin_VI
ADwin_Gold2.close_all()
ad = ADwin_Gold2("adwin",
                 r"C:\Users\nicolas.roch\Measurements\Drivers\adwin\nanoqt\ressources\ADwin11.btl",
                 r"C:\Users\nicolas.roch\Measurements\Drivers\adwin\nanoqt\ressources\acquisition-gold2.TB1")
# Out:
# Connected to: None adwin (serial:None, firmware:None) in 0.26s

# %% [markdown]
# <h4  style="color:#4697E8";>Connect to the Rohde&Schwartz VNA</h4>

# %%
from VNA_RS import ZNB
#from VNA_ZNB20 import ZNB
#from VNA_ZNB20 import ZNBChannel

try:
    vna = ZNB('ZNB20', 'TCPIP0::192.168.0.9::inst0::INSTR',
               init_s_params=False,terminator='\n')
except KeyError as er:
    ZNB.close_all() # Disconnect and irreversibly tear down the instrument
    vna = ZNB('ZNB20', 'TCPIP0::192.168.0.9::inst0::INSTR',
               init_s_params=False,terminator='\n')
    
vna.clear_channels()

vna.add_channel('S21', vna_parameter='S21');
s21 = vna.channels.S21

#vna.add_channel('S11', vna_parameter='S11');
#s11 = vna.channels.S11
# Out:
# Connected to: Rohde-Schwarz ZNB20-2Port (serial:1311601062101578, firmware:2.80) in 0.02s

# %% [markdown]
# <h4 style="color:#4697E8";>Connect to the Agilent signal generator</h4>

# %%
from Agilent_E8257D import E8257D

try:
    mw_source = E8257D('mw_source','TCPIP0::192.168.0.70::inst0::INSTR')
except KeyError as er:
    E8257D.close_all()
    mw_source = E8257D('mw_source','TCPIP0::192.168.0.70::inst0::INSTR')
# Out:
# Connected to: Agilent Technologies E8257D (serial:US45470698, firmware:C.06.28) in 0.03s

# %% [markdown]
# <h4 style="color:#4697E8";>Connect to the Rohde&Schwartz signal generator</h4>

# %%
from RS_SMB_100A import SMB100A

#try:
#    mw_source_rs = SGS100A('pump_source','USB0::0x0AAD::0x0088::112061::INSTR')
#except KeyError as er:
#    SGS100A.close_all()
#    mw_source_rs = SGS100A('pump_source','USB0::0x0AAD::0x0088::112061::INSTR')

# %% [markdown]
# <h4 style="color:#4697E8";>Connect to the HP3245A current generator</h4>

# %%
from HP3245A import HP3245A

try:
    I_source = HP3245A('current_source', 'GPIB0::9::INSTR')

except KeyError as er:
    HP3245A.close_all() #Disconnect and irreversibly tear down the instrument
    I_source = HP3245A('current_source', 'GPIB0::9::INSTR')
I_source.output_terminal('REAR')
# Out:
# Connected to: HEWLETT PACKARD None (serial:None, firmware:None) in 0.06s

# %% [markdown]
# <h4 style="color:#4697E8";>Connect to the SR830 lock-in amplifier</h4>

# %%
from qcodes.instrument_drivers.stanford_research.SR830 import SR830

try:
    li = SR830('lockin', 'GPIB0::7::INSTR')

except KeyError as er:
    SR830.close_all() #Disconnect and irreversibly tear down the instrument
    li = SR830('lockin', 'GPIB0::7::INSTR')
# Out:
# 2022-03-04 16:23:44,301 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 109 ¦ C:\Users\nicolas.roch\Miniconda3\envs\measurement\lib\site-packages\qcodes\instrument\base.py:128: QCoDeSDeprecationWarning: Parameter ch1_databuffer on instrument lockin does not correctly pass kwargs to its baseclass. A Parameter class must take `**kwargs` and forward them to its baseclass.
#   warnings.warn(
#
# 2022-03-04 16:23:44,322 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 109 ¦ C:\Users\nicolas.roch\Miniconda3\envs\measurement\lib\site-packages\qcodes\instrument\base.py:128: QCoDeSDeprecationWarning: Parameter ch2_databuffer on instrument lockin does not correctly pass kwargs to its baseclass. A Parameter class must take `**kwargs` and forward them to its baseclass.
#   warnings.warn(
# Connected to: Stanford_Research_Systems SR830 (serial:s/n83156, firmware:ver1.07) in 0.09s

# %% [markdown]
# <h4 style="color:#4697E8";>Connect to the FSV3030 spectrum analyser</h4>

# %%
from RS_FSV import RS_FSV

#try:
#    spectrum_analyser = RS_FSV('spectrum_analyser', 'TCPIP0::192.168.0.66::inst0::INSTR')

#except KeyError as er:
#    RS_FSV.close_all() #Disconnect and irreversibly tear down the instrument
#    spectrum_analyser = RS_FSV('spectrum_analyser', 'TCPIP0::192.168.0.66::inst0::INSTR')

# %% [markdown]
# <h4 style="color:#4697E8";>Connect to the Signal Hound spectrum analyser</h4>

# %%
from SignalHound_USB_SA124B import SignalHound_USB_SA124B
# SignalHound_USB_SA124B.close_all()
sh = SignalHound_USB_SA124B('signal_hound', dll_path='C:\\Program Files\\Signal Hound\\Spike\\sa_api.dll')
# Out:
# 2022-03-04 16:23:45,275 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 109 ¦ C:\Users\nicolas.roch\Miniconda3\envs\measurement\lib\site-packages\qcodes\instrument\base.py:128: QCoDeSDeprecationWarning: Parameter trace on instrument signal_hound does not correctly pass kwargs to its baseclass. A Parameter class must take `**kwargs` and forward them to its baseclass.
#   warnings.warn(
# Connected to: Signal Hound sa124B (serial:20234172, firmware:Version 3.13) in 7.26s

# %% [markdown]
# <h4 style="color:#4697E8";>Connect to the AFG3252 arbitrary function generator</h4>

# %%
from qcodes_contrib_drivers.drivers.Tektronix.AFG3000 import AFG3000 

try:
    afg = AFG3000('function_generator', 'TCPIP0::192.168.0.12::inst0::INSTR')

except KeyError as er:
    AFG3000.close_all() # Disconnect and irreversibly tear down the instrument
    afg = AFG3000('function_generator', 'TCPIP0::192.168.0.12::inst0::INSTR')
# Out:
# Connected to: TEKTRONIX AFG3252 (serial:C011080, firmware:SCPI:99.0 FV:1.2.1) in 4.03s

# %% [markdown]
# <h4 style="color:#4697E8";>Dummies</h4>

# %%
# dac = DummyInstrument('dac', gates=['ch1', 'ch2'])
# dmm = DummyInstrumentWithMeasurement('dmm', setter_instr=dac)

# %% [markdown]
# <h3 style="color:#418FDB";>Adding the instruments to the station</h3>

# %%
STATION.add_component(s21)         # VNA channel s21
STATION.add_component(mw_source)   # Signal generator
STATION.add_component(ad)          # ADwin
STATION.add_component(I_source)
STATION.add_component(li)
STATION.add_component(sh)
STATION.add_component(afg)

#STATION.add_component(daq)        # Dummy signal
#STATION.add_component(dmm)        # Dummy multimeter

STATION.snapshot();
STATION.components
# Out:
# 2022-03-04 16:23:56,612 ¦ qcodes.instrument.base ¦ WARNING ¦ base ¦ snapshot_base ¦ 259 ¦ [ZNB20_S21(VNAChannel)] Snapshot: Could not update parameter: trigger_link
# 2022-03-04 16:24:01,745 ¦ qcodes.instrument.base ¦ WARNING ¦ base ¦ snapshot_base ¦ 259 ¦ [mw_source(E8257D)] Snapshot: Could not update parameter: sweepmode
# 2022-03-04 16:24:01,772 ¦ qcodes.instrument.base ¦ WARNING ¦ base ¦ snapshot_base ¦ 259 ¦ [adwin(ADwin_Gold2)] Snapshot: Could not update parameter: outputs
# 2022-03-04 16:24:01,774 ¦ qcodes.instrument.base ¦ WARNING ¦ base ¦ snapshot_base ¦ 259 ¦ [adwin(ADwin_Gold2)] Snapshot: Could not update parameter: inputs
# 2022-03-04 16:24:02,084 ¦ SignalHound_USB_SA124B ¦ WARNING ¦ SignalHound_USB_SA124B ¦ check_for_error ¦ 742 ¦ During call of saConfigSweepCoupling the followingWarning: saParameterClamped was raised
# {'ZNB20_S21': <VNAChannel: ZNB20_S21 of ZNB: ZNB20>,
#  'mw_source': <E8257D: mw_source>,
#  'adwin': <ADwin_Gold2: adwin>,
#  'current_source': <HP3245A: current_source>,
#  'lockin': <SR830: lockin>,
#  'signal_hound': <SignalHound_USB_SA124B: signal_hound>,
#  'function_generator': <AFG3000: function_generator>}

# %% [markdown]
# <h2 style="color:#1C3C5C";>Measurements</h2>
# Here the idea is to create a new cell and a new experiment every time something more that just ranges and parameters are changed. Every new measurement will be stored in the database with a different experiment name, so it's easyer to retrive. Note that the used instruments must be initialised before, in the Instrument Initialisation section.

# %% [markdown]
# <h3 style="color:#418FDB";>VNA trace and DC or flux bias</h3>

# %% [markdown]
# <h4  style="color:#4697E8";>Phase and magnitude of the current trace</h4>

# %%
experiment_name = 's21'
measurement_name = 'vna_1dtrce_p0dbm_cnt5ghz_spn8ghz'
exp = load_or_create_experiment(experiment_name=experiment_name, sample_name=sample_name)

s21.center(5e9)
s21.span(8e9)
# s21.start(2e9)
# s21.stop(10e9)
s21.npts(10001)
s21.bandwidth(1e3)
s21.averaging_enabled(True)
s21.avg(10)
# 30dB of attenuation added at the output
s21.power(0)

s21.set_electrical_delay_auto()
s21.average_clear()
# ad.go_to_zero()

vna.rf_on()
res = do0d(s21.trace_mag_phase, measurement_name=measurement_name);
vna.rf_off()

res[0].captured_run_id
# Out:
# Starting experimental run with id: 5. Using 'qcodes.utils.dataset.doNd.do0d'
# 5

# %% [markdown]
# <h4  style="color:#4697E8";>Phase and magnitude of traces corresponding to different power levels</h4>

# %%
experiment_name = 's21'
measurement_name = 'vna_2dtrce_413ghz_vs_p'
exp = load_or_create_experiment(experiment_name=experiment_name, sample_name=sample_name)

s21.center(4.113e9)
s21.span(500e6)
# s21.start(2e9)
# s21.stop(10e9)
s21.npts(2001)
s21.bandwidth(1e3)
s21.averaging_enabled(True)
s21.avg(5)
# 30dB of attenuation added at the output

vna.rf_on()
res = do1d(s21.power, -20, 10, 31, 0.01, s21.trace_mag_phase, measurement_name=measurement_name);
vna.rf_off()

res[0].captured_run_id
# Out:
# Starting experimental run with id: 8. Using 'qcodes.utils.dataset.doNd.do1d'
#   0%|          | 0/31 [00:00<?, ?it/s]
# 8

# %% [markdown]
# <h4  style="color:#4697E8";>Phase and magnitude of traces vs flux</h4>

# %%
experiment_name = 's21'
measurement_name = 'vna_zeroed_2dtrce_3-9ghz_vs_flux'
exp = load_or_create_experiment(experiment_name=experiment_name, sample_name=sample_name)

s21.start(3e9)
s21.stop(9e9)
s21.power(3)
s21.npts(5001)
s21.bandwidth(1e3)
s21.averaging_enabled(True)
s21.avg(3)
# 30dB of attenuation added at the output
I_source.current(0.0)

vna.rf_on()
res = do1d(I_source.current, -10e-3, 10e-3, 101, 0.01, s21.trace_mag_phase, measurement_name=measurement_name);
vna.rf_off()

res[0].captured_run_id
# Out:
# Starting experimental run with id: 12. Using 'qcodes.utils.dataset.doNd.do1d'
#   0%|          | 0/101 [00:00<?, ?it/s]
# 12

# %% [markdown]
# <h4  style="color:#4697E8";>Phase and magnitude of traces vs DC bias</h4>

# %%
experiment_name = 's21'
measurement_name = 's21_vs_dc'
exp = load_or_create_experiment(experiment_name=experiment_name, sample_name=sample_name)

# %%
adVbias = Parameter(name='adwin_output1',
                    label='Adwin output voltage',
                    unit= 'V',
                    vals=validators.Numbers(-10,10),
                    get_cmd=None,
                    set_cmd=None
                   )

# %%
meas = qc.Measurement(exp=exp, station=STATION, name='vna_trace_highp_mwoff_vs_dc_bias_pm5')

# mw
# f = 4.04e9
# p = -5.5
# mw_source.frequency(f)
# mw_source.power(p)

s21.center(4.13e9)
s21.span(1e9)
s21.npts(2001)
s21.bandwidth(1e3)
s21.averaging_enabled(True)
s21.avg(2)
# 30dB of attenuation added at the output
s21.power(4)

# s21.set_electrical_delay_auto()
s21.average_clear()

ad.input_mask(0b1)
ad.output_mask(0b11)
ad.adwin_mode(0b0)
ad.clear_fifos()
ad.go_to_zero()

VT = 2.5
I = 0e-3
offset = 0.0
I_source.current(I)
ad_Vs = np.linspace(-VT+offset,VT+offset, num=201)

meas.register_parameter(adVbias)
meas.register_parameter(s21.trace_mag_phase, setpoints=[adVbias])

vna.rf_on()

with meas.run() as datasaver :
    for v_ad in tqdm.tqdm(ad_Vs):
        adwin_target = np.array([v_ad, v_ad])
        ad.outputs(adwin_target)
        ad.launch_measurement()
        ad.clear_fifos()
        
        trace = s21.trace_mag_phase()
        datasaver.add_result((adVbias, v_ad),
                             (s21.trace_mag_phase, trace))

vna.rf_off()
ad.clear_fifos()
ad.go_to_zero()
I_source.current(0.0)

# res[0].captured_run_id
# Out:
# Starting experimental run with id: 26.
#   0%|          | 0/201 [00:00<?, ?it/s]
# [-2.5 -2.5]
# [-2.475 -2.475]
# [-2.45 -2.45]
# [-2.425 -2.425]
# [-2.4 -2.4]
# [-2.375 -2.375]
# [-2.35 -2.35]
# [-2.325 -2.325]
# [-2.3 -2.3]
# [-2.275 -2.275]
# [-2.25 -2.25]
# [-2.225 -2.225]
# [-2.2 -2.2]
# [-2.175 -2.175]
# [-2.15 -2.15]
# [-2.125 -2.125]
# [-2.1 -2.1]
# [-2.075 -2.075]
# [-2.05 -2.05]
# [-2.025 -2.025]
# [-2. -2.]
# [-1.975 -1.975]
# [-1.95 -1.95]
# [-1.925 -1.925]
# [-1.9 -1.9]
# [-1.875 -1.875]
# [-1.85 -1.85]
# [-1.825 -1.825]
# [-1.8 -1.8]
# [-1.775 -1.775]
# [-1.75 -1.75]
# [-1.725 -1.725]
# [-1.7 -1.7]
# Received SIGINT, Will interrupt at first suitable time. Send second SIGINT to interrupt immediately.
# 2022-02-09 13:48:06,304 ¦ qcodes.dataset.measurements ¦ WARNING ¦ measurements ¦ __exit__ ¦ 646 ¦ An exception occured in measurement with guid: aaaaaaaa-0000-0000-0000-017ede84c755;
# Traceback:
# Traceback (most recent call last):
#   File "C:\Users\NICOLA~1.ROC\AppData\Local\Temp/ipykernel_11896/2214503715.py", line 46, in <module>
#     trace = s21.trace_mag_phase()
#   File "C:\Users\nicolas.roch\Miniconda3\envs\measurement\lib\site-packages\qcodes\instrument\parameter.py", line 447, in __call__
#     return self.get()
#   File "C:\Users\nicolas.roch\Miniconda3\envs\measurement\lib\site-packages\qcodes\instrument\parameter.py", line 637, in get_wrapper
#     raw_value = get_function(*args, **kwargs)
#   File "C:\Users\nicolas.roch\Measurements\Drivers\VNA_RS.py", line 246, in get_raw
#     data = self.instrument._get_sweep_data(force_polar=True)
#   File "C:\Users\nicolas.roch\Measurements\Drivers\VNA_RS.py", line 884, in _get_sweep_data
#     self.write(
#   File "C:\Users\nicolas.roch\Miniconda3\envs\measurement\lib\site-packages\qcodes\instrument\channel.py", line 55, in write
#     return self._parent.write(cmd)
#   File "C:\Users\nicolas.roch\Miniconda3\envs\measurement\lib\site-packages\qcodes\instrument\base.py", line 756, in write
#     self.write_raw(cmd)
#   File "C:\Users\nicolas.roch\Miniconda3\envs\measurement\lib\site-packages\qcodes\instrument\visa.py", line 221, in write_raw
#     self.visa_handle.write(cmd)
#   File "C:\Users\nicolas.roch\Miniconda3\envs\measurement\lib\site-packages\qcodes\utils\delaykeyboardinterrupt.py", line 56, in __exit__
#     self.old_handler(*self.signal_received)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\NICOLA~1.ROC\AppData\Local\Temp/ipykernel_11896/2214503715.py in <module>
#      44         ad.clear_fifos()
#      45
# ---> 46         trace = s21.trace_mag_phase()
#      47         datasaver.add_result((adVbias, v_ad),
#      48                              (s21.trace_mag_phase, trace))
#
# ~\Miniconda3\envs\measurement\lib\site-packages\qcodes\instrument\parameter.py in __call__(self, *args, **kwargs)
#     445         if len(args) == 0 and len(kwargs) == 0:
#     446             if self.gettable:
# --> 447                 return self.get()
#     448             else:
#     449                 raise NotImplementedError('no get cmd found in' +
#
# ~\Miniconda3\envs\measurement\lib\site-packages\qcodes\instrument\parameter.py in get_wrapper(*args, **kwargs)
#     635             try:
#     636                 # There might be cases where a .get also has args/kwargs
# --> 637                 raw_value = get_function(*args, **kwargs)
#     638
#     639                 value = self._from_raw_value_to_value(raw_value)
#
# ~\Measurements\Drivers\VNA_RS.py in get_raw(self)
#     244         """
#     245         with self.instrument.format.set_to("dB"):
# --> 246             data = self.instrument._get_sweep_data(force_polar=True)
#     247         return abs(data), np.angle(data)
#     248
#
# ~\Measurements\Drivers\VNA_RS.py in _get_sweep_data(self, force_polar)
#     882                     for _ in range(self.avg()):
#     883                         self.write(f"INIT{self._instrument_channel}:IMM; *WAI")
# --> 884                     self.write(
#     885                         f"CALC{self._instrument_channel}:PAR:SEL "
#     886                         f"'{self._tracename}'"
#
# ~\Miniconda3\envs\measurement\lib\site-packages\qcodes\instrument\channel.py in write(self, cmd)
#      53     # Pass any commands to read or write from the instrument up to the parent
#      54     def write(self, cmd: str) -> None:
# ---> 55         return self._parent.write(cmd)
#      56
#      57     def write_raw(self, cmd: str) -> None:
#
# ~\Miniconda3\envs\measurement\lib\site-packages\qcodes\instrument\base.py in write(self, cmd)
#     754         """
#     755         try:
# --> 756             self.write_raw(cmd)
#     757         except Exception as e:
#     758             inst = repr(self)
#
# ~\Miniconda3\envs\measurement\lib\site-packages\qcodes\instrument\visa.py in write_raw(self, cmd)
#     219         with DelayedKeyboardInterrupt():
#     220             self.visa_log.debug(f"Writing: {cmd}")
# --> 221             self.visa_handle.write(cmd)
#     222
#     223     def ask_raw(self, cmd: str) -> str:
#
# ~\Miniconda3\envs\measurement\lib\site-packages\qcodes\utils\delaykeyboardinterrupt.py in __exit__(self, exception_type, value, traceback)
#      54             if (self.old_handler is not None and
#      55                     not isinstance(self.old_handler, int)):
# ---> 56                 self.old_handler(*self.signal_received)
#
# KeyboardInterrupt:

# %% [markdown]
# <h3 style="color:#418FDB";>VNA trace and microwave tone</h3>

# %% [markdown]
# <h4  style="color:#4697E8";>VNA CW and signal generator power and frequency sweep (two tones spectroscopy)</h4>

# %%
experiment_name = 'two_tones'
measurement_name = 'meas_4.1_tone_0.1_25ghz_long'
exp = load_or_create_experiment(experiment_name=experiment_name, sample_name=sample_name)

#set the vna parameters
s21.npts(1)
s21.center(4.13e9)
s21.bandwidth(1e2)
#s21.span(1e3)
s21.averaging_enabled(True)
s21.avg(1)
s21.power(0)
#s21.set_electrical_delay_auto()

# set the signal generator parameters
mw_source.sourcemode('CW')
mw_source.phase(0)

start_frequency = 100e6
stop_frequency = 25e9
step_frequency = 1e6
frequency_points = int( (stop_frequency-start_frequency)/step_frequency )

start_power = -20
stop_power = 10
step_power = 1
power_points = int( (stop_power-start_power)/step_power )

dwell_time = 0.005

I_source.current(0.0)
ad.go_to_zero()

# WARNING! It takes too much time for some reasons
vna.rf_on()
mw_source.status('ON')
res = do2d(mw_source.power, start_power, stop_power, power_points, dwell_time,
           mw_source.frequency, start_frequency, stop_frequency, frequency_points, dwell_time, 
           s21.trace_mag_phase, measurement_name=measurement_name, do_plot=False);
mw_source.status('OFF')
vna.rf_off()
# Out:
# Starting experimental run with id: 22. Using 'qcodes.utils.dataset.doNd.do2d'
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/24900 [00:00<?, ?it/s]
#   0%|          | 0/24900 [00:00<?, ?it/s]
#   0%|          | 0/24900 [00:00<?, ?it/s]
#   0%|          | 0/24900 [00:00<?, ?it/s]
#   0%|          | 0/24900 [00:00<?, ?it/s]
#   0%|          | 0/24900 [00:00<?, ?it/s]
#   0%|          | 0/24900 [00:00<?, ?it/s]
#   0%|          | 0/24900 [00:00<?, ?it/s]
#   0%|          | 0/24900 [00:00<?, ?it/s]
#   0%|          | 0/24900 [00:00<?, ?it/s]
#   0%|          | 0/24900 [00:00<?, ?it/s]
#   0%|          | 0/24900 [00:00<?, ?it/s]
#   0%|          | 0/24900 [00:00<?, ?it/s]
#   0%|          | 0/24900 [00:00<?, ?it/s]
#   0%|          | 0/24900 [00:00<?, ?it/s]
#   0%|          | 0/24900 [00:00<?, ?it/s]
#   0%|          | 0/24900 [00:00<?, ?it/s]
#   0%|          | 0/24900 [00:00<?, ?it/s]
#   0%|          | 0/24900 [00:00<?, ?it/s]
#   0%|          | 0/24900 [00:00<?, ?it/s]
#   0%|          | 0/24900 [00:00<?, ?it/s]
#   0%|          | 0/24900 [00:00<?, ?it/s]
#   0%|          | 0/24900 [00:00<?, ?it/s]
#   0%|          | 0/24900 [00:00<?, ?it/s]
#   0%|          | 0/24900 [00:00<?, ?it/s]
#   0%|          | 0/24900 [00:00<?, ?it/s]
#   0%|          | 0/24900 [00:00<?, ?it/s]
#   0%|          | 0/24900 [00:00<?, ?it/s]
#   0%|          | 0/24900 [00:00<?, ?it/s]
#   0%|          | 0/24900 [00:00<?, ?it/s]

# %% [markdown]
# <h4  style="color:#4697E8";>Phase and magnitude of traces with mw tone vs mw frequency</h4>

# %%
experiment_name = 's21'
exp = load_or_create_experiment(experiment_name=experiment_name, sample_name=sample_name)

# mw
f = 3.2e9
df = 100e6
p = -11.5
measurement_name = 'vna_2dtrce_fcnt' + str(int(f/1e7)) + '_p'  + str(int(p*10))

# vna
s21.center(f)
s21.span(250e6)
s21.power(0)
s21.npts(2501)
s21.bandwidth(1e3)
s21.averaging_enabled(True)
s21.avg(3)
# 30dB of attenuation added at the output
I_source.current(0.0)

vna.rf_on()
mw_source.power(p)
mw_source.status('ON')
res = do1d(mw_source.frequency, f-df, f+df, 201, 0.01, s21.trace_mag_phase, measurement_name=measurement_name);
mw_source.status('OFF')
vna.rf_off()

res[0].captured_run_id
# Out:
# Starting experimental run with id: 103. Using 'qcodes.utils.dataset.doNd.do1d'
#   0%|          | 0/201 [00:00<?, ?it/s]
# 103

# %% [markdown]
# <h4  style="color:#4697E8";>Phase and magnitude of traces with mw tone vs mw power</h4>

# %%
experiment_name = 's21'
exp = load_or_create_experiment(experiment_name=experiment_name, sample_name=sample_name)

# mw
f = 3.20e9
p_low = -30
p_high = -7
measurement_name = 'vna_2dtrce_f' + str(int(f/1e7)) + '_phigh'  + str(int(p_high)) + 'dBm'

# vna
s21.center(f)
s21.span(250e6)
s21.power(3)
s21.npts(2501)
s21.bandwidth(1e3)
s21.averaging_enabled(True)
s21.avg(3)
# 30dB of attenuation added at the output
I_source.current(0.0)

vna.rf_on()
mw_source.frequency(f)
mw_source.status('ON')
res = do1d(mw_source.power, p_low, p_high, 251, 0.01, s21.trace_mag_phase, measurement_name=measurement_name);
mw_source.status('OFF')
vna.rf_off()

res[0].captured_run_id
# Out:
# Starting experimental run with id: 106. Using 'qcodes.utils.dataset.doNd.do1d'
#   0%|          | 0/251 [00:00<?, ?it/s]
# 106

# %% [markdown]
# <h4  style="color:#4697E8";>Phase and magnitude of traces with mw tone vs DC bias</h4>

# %%
experiment_name = 'vna_bloch_osc'
measurement_name = 'vna_2dtrace_mwon_dcbias'
exp = load_or_create_experiment(experiment_name=experiment_name, sample_name=sample_name)

# %%
adVbias = Parameter(name='adwin_output1',
                    label='Adwin output voltage',
                    unit= 'V',
                    vals=validators.Numbers(-10,10),
                    get_cmd=None,
                    set_cmd=None
                   )

# %%
meas = qc.Measurement(exp=exp, station=STATION, name='vna_trace_narrowspan_mwon_f404p-55_vs_dc_bias_pm5')

# mw
f = 4.04e9
p = -5.5
mw_source.frequency(f)
mw_source.power(p)

s21.center(f)
s21.span(2e6)
s21.npts(1001)
s21.bandwidth(1e2)
s21.averaging_enabled(True)
s21.avg(2)
# 30dB of attenuation added at the output
s21.power(0)

# s21.set_electrical_delay_auto()
s21.average_clear()

ad.input_mask(0b1)
ad.output_mask(0b11)
ad.adwin_mode(0b0)
ad.clear_fifos()
ad.go_to_zero()

VT = 0.2
I = 0e-3
offset = 2.0
I_source.current(I)
ad_Vs = np.linspace(-VT+offset,VT+offset, num=21)

meas.register_parameter(adVbias)
meas.register_parameter(s21.trace_mag_phase, setpoints=[adVbias])

vna.rf_on()
mw_source.status('ON')

with meas.run() as datasaver :
    for v_ad in tqdm.tqdm(ad_Vs):
        adwin_target = np.array([v_ad, v_ad])
        ad.outputs(adwin_target)
        ad.launch_measurement()
        ad.clear_fifos()
        
        trace = s21.trace_mag_phase()
        datasaver.add_result((adVbias, v_ad),
                             (s21.trace_mag_phase, trace))

mw_source.status('OFF')
vna.rf_off()
ad.clear_fifos()
ad.go_to_zero()
I_source.current(0.0)

# res[0].captured_run_id
# Out:
# Starting experimental run with id: 97.
#   0%|          | 0/21 [00:00<?, ?it/s]

# %% [markdown]
# <h4  style="color:#4697E8";>Phase and magnitude of traces with mw tone vs flux</h4>

# %%
experiment_name = 's21'
exp = load_or_create_experiment(experiment_name=experiment_name, sample_name=sample_name)

# mw
f = 4.04e9
p = -5.5
measurement_name = 'vna_2dtrce_fluxsweep_f' + str(int(f/1e7)) + '_p'  + str(int(p)) + 'dBm'

# vna
s21.center(f)
s21.span(20e6)
s21.power(0)
s21.npts(2501)
s21.bandwidth(1e3)
s21.averaging_enabled(True)
s21.avg(5)
# 30dB of attenuation added at the output
I_source.current(0.0)

vna.rf_on()
mw_source.frequency(f)
mw_source.power(p)
mw_source.status('ON')
res = do1d(I_source.current, -15e-3, 15e-3, 151, 0.01, s21.trace_mag_phase, measurement_name=measurement_name);
mw_source.status('OFF')
vna.rf_off()

res[0].captured_run_id
# Out:
# Starting experimental run with id: 84. Using 'qcodes.utils.dataset.doNd.do1d'
#   0%|          | 0/151 [00:00<?, ?it/s]
# 84

# %% [markdown]
# <h3  style="color:#418FDB";>IV curve and microwave tone</h3>

# %% [markdown]
# <h4 style="color:#4697E8";>Adwin and fixed tone</h4>

# %%
experiment_name = 'iv_curves'
measurement_name = "iv_mwon_step_zoom_p202_10001pts_21avg"
exp = load_or_create_experiment(experiment_name=experiment_name, sample_name=sample_name)

# %%
ad.input_mask(0b11)
ad.output_mask(0b11)
ad.adwin_mode(0b0)
ad.clear_fifos()
ad.go_to_zero()
VT = 5.
offset = 0
ramp_param = ADwin_averagedRamp(measurement_name,
                        ad, 
                        period=20.2, 
                        n_pts=50001,
                        N_ramp=21,
                        Vs_high=np.array([VT+offset, -VT+offset]),
                        Vs_low=np.array([-VT+offset, VT+offset]),
                        progress= True)

easy_iv = ADwin_IV(ramp_param.name+'_iv', ramp_param,
                  voltage_input=2,
                  current_input=1,
                  voltage_divider_value=1,
                  current_coefficient=1e7)

# %%
f = 4.04e9
p = -5.5
Ib = 0e-3
    
# meas_name = 'iv_mwoff_101avg_p16_pm10mV'
meas = qc.Measurement(exp=exp, station=STATION, name = measurement_name)

# flux
I_source.current(Ib)

# mw
mw_source.power(p)
mw_source.frequency(f)
mw_source.status('OFF')

# logging
meas.register_parameter(mw_source.frequency)
meas.register_parameter(mw_source.power)
meas.register_parameter(easy_iv)
meas.write_period = 10

# measurement
with meas.run() as datasaver:
    get_iv = easy_iv() 
    datasaver.add_result((easy_iv, get_iv))

# turn off
mw_source.status('OFF')
ad.go_to_zero()
I_source.current(0.0)
# Out:
# Starting experimental run with id: 40.
#   0%|          | 0/1302 [00:00<?, ?it/s]

# %% [markdown]
# <h4 style="color:#4697E8";>Adwin vs flux</h4>

# %%
experiment_name = 'iv_curves'
measurement_name = 'iv_pm03mV_flux_p52_20001pts_21avg'
exp = load_or_create_experiment(experiment_name=experiment_name, sample_name=sample_name)

# %%
ad.input_mask(0b11)
ad.output_mask(0b11)
ad.adwin_mode(0b0)
ad.clear_fifos()
ad.go_to_zero()
VT = 10.
offset = 0
ramp_param = ADwin_averagedRamp(measurement_name,
                        ad, 
                        period=5.2,
                        n_pts=20001,
                        N_ramp=21,
                        Vs_high=np.array([VT+offset, -VT+offset]),
                        Vs_low=np.array([-VT+offset, VT+offset]),
                        progress= False)

easy_iv = ADwin_IV(ramp_param.name+'_iv', ramp_param,
                  voltage_input=2,
                  current_input=1,
                  voltage_divider_value=1e3*30,
                  current_coefficient=1e9)

# %%
meas = qc.Measurement(exp=exp, station=STATION, name=measurement_name)

# flux
currents = np.linspace(-20e-3,  20e-3, num=501)

# logging
meas.register_parameter(I_source.current)
meas.register_parameter(easy_iv, setpoints=[I_source.current])
meas.write_period = 10

# measurement
with meas.run() as datasaver:
    for I in tqdm.tqdm(currents):
        I_source.current(I)
        get_iv = easy_iv() 

        datasaver.add_result((easy_iv, get_iv),
                             (I_source.current, I))
        
I_source.current(0)
# Out:
# Starting experimental run with id: 13.
#   0%|          | 0/501 [00:00<?, ?it/s]

# %% [markdown]
# <h4 style="color:#4697E8";>Adwin vs tone frequency</h4>

# %%
experiment_name = 'iv_curves'
measurement_name = 'iv_vs_f'
exp = load_or_create_experiment(experiment_name=experiment_name, sample_name=sample_name)

# %%
ad.input_mask(0b11)
ad.output_mask(0b11)
ad.adwin_mode(0b0)
ad.clear_fifos()
ad.go_to_zero()
VT = 5
offset = 0
ramp_param = ADwin_averagedRamp("iv_pm5_p02_10001pts_11avg_freqs", 
                        ad, 
                        period=0.2, 
                        n_pts=10001,
                        N_ramp=11,
                        Vs_high=np.array([VT+offset, -VT+offset]),
                        Vs_low=np.array([-VT+offset, VT+offset]),
                        progress= False)

easy_iv = ADwin_IV(ramp_param.name+'_iv', ramp_param,
                  voltage_input=2,
                  current_input=1,
                  voltage_divider_value=1000,
                  current_coefficient=1e9)

# %%
meas_name = 'iv_fsweep_mwon_p-11dbm_pm5mV'
meas = qc.Measurement(exp=exp, station=STATION, name = meas_name)

# flux
I_source.current(0e-3)

# mw power and frequency sweep
pwr = -11.5
frequency = 3.16e9
frequency_array = np.linspace(frequency - 50e6, frequency + 50e6, num=101)
mw_source.status('ON')

# logging
meas.register_parameter(mw_source.frequency)
meas.register_parameter(mw_source.power)
meas.register_parameter(easy_iv, setpoints=[mw_source.frequency, mw_source.power])
meas.write_period = 10

with meas.run() as datasaver:

    for frq in tqdm.tqdm(frequency_array):
        # VNA.channels.S21.power(pow)
        mw_source.frequency(frq)
        mw_source.power(pwr)
        get_iv = easy_iv() 

        datasaver.add_result((easy_iv, get_iv),
                             (mw_source.frequency, frq),
                             (mw_source.power, pwr))

    I_source.current(0)
    
mw_source.status('OFF')
# Out:
# Starting experimental run with id: 80.
#   0%|          | 0/101 [00:00<?, ?it/s]

# %% [markdown]
# <h4 style="color:#4697E8";>Adwin vs tone power</h4>

# %%
experiment_name = 'iv_w_steps_power_sweep'
exp = load_or_create_experiment(experiment_name=experiment_name, sample_name=sample_name)

# %%
ad.input_mask(0b11)
ad.output_mask(0b11)
ad.adwin_mode(0b0)
ad.clear_fifos()
ad.go_to_zero()
VT = 1
offset = 2
ramp_param = ADwin_averagedRamp("iv_steps_pwr_sweep_100_05s", 
                        ad, 
                        period=0.4, 
                        n_pts=10001,
                        N_ramp=51,
                        Vs_high=np.array([VT+offset, -VT+offset]),
                        Vs_low=np.array([-VT+offset, VT+offset]),
                        progress= False)

easy_iv = ADwin_IV(ramp_param.name+'_iv', ramp_param,
                  voltage_input=2,
                  current_input=1,
                  voltage_divider_value=1e3,
                  current_coefficient=1e9)

# %%
f =3.2e9
p = -11.5
dp = 1
p_number = 301

measurement_name = 'iv_steps_f' + str(int(f/1e7)) + '_pwr_sweep'
meas = qc.Measurement(exp=exp, station=STATION, name = measurement_name)

# flux
I_source.current(0e-3)

# mw power and frequency sweep
frequency = f
pmin = p - dp
pmax = p + dp
power_array = np.linspace(pmin, pmax, num=p_number)
mw_source.status('ON')

# logging
meas.register_parameter(mw_source.frequency)
meas.register_parameter(mw_source.power)
meas.register_parameter(easy_iv, setpoints=[mw_source.frequency, mw_source.power])
meas.write_period = 10

with meas.run() as datasaver:

    for pwr in tqdm.tqdm(power_array):
        # VNA.channels.S21.power(pow)
        mw_source.frequency(frequency)
        mw_source.power(pwr)
        time.sleep(0.05)
        get_iv = easy_iv() 

        datasaver.add_result((easy_iv, get_iv),
                             (mw_source.frequency, frequency),
                             (mw_source.power, pwr))

    I_source.current(0)

mw_source.status('OFF')
# Out:
# Starting experimental run with id: 21.
#   0%|          | 0/1001 [00:00<?, ?it/s]
# Starting experimental run with id: 22.
#   0%|          | 0/1001 [00:00<?, ?it/s]
# Starting experimental run with id: 23.
#   0%|          | 0/1001 [00:00<?, ?it/s]
# Starting experimental run with id: 24.
#   0%|          | 0/1001 [00:00<?, ?it/s]
# Starting experimental run with id: 25.
#   0%|          | 0/1001 [00:00<?, ?it/s]

# %% [markdown]
# <h4 style="color:#4697E8";>Adwin with mw tone vs flux</h4>

# %%
experiment_name = 'iv_curves_sweeps'
measurement_name = 'iv_mw_vs_flux'
exp = load_or_create_experiment(experiment_name=experiment_name, sample_name=sample_name)

# %%
ad.input_mask(0b11)
ad.output_mask(0b11)
ad.adwin_mode(0b0)
ad.clear_fifos()
ad.go_to_zero()
VT = 5
offset = 0
ramp_param = ADwin_averagedRamp("iv_pm5_p02_10001pts_101av_flux",
                        ad, 
                        period=0.2, 
                        n_pts=10001,
                        N_ramp=11,
                        Vs_high=np.array([VT+offset, -VT+offset]),
                        Vs_low=np.array([-VT+offset, VT+offset]),
                        progress= False)

easy_iv = ADwin_IV(ramp_param.name+'_iv', ramp_param,
                  voltage_input=2,
                  current_input=1,
                  voltage_divider_value=1e3,
                  current_coefficient=1e9)

# %%
meas = qc.Measurement(exp=exp, station=STATION, name='iv_mwon_f404p-55_pm5mv_fluxsweep')

# flux
currents = np.linspace(-10e-3,  10e-3, num=201)

# mw
f = 4.04e9
p = -5.5
mw_source.frequency(f)
mw_source.power(p)
mw_source.status('ON')

# logging
meas.register_parameter(I_source.current)
meas.register_parameter(easy_iv, setpoints=[I_source.current])
meas.write_period = 10

# measurement
with meas.run() as datasaver:
    for I in tqdm.tqdm(currents):
        I_source.current(I)
        get_iv = easy_iv() 

        datasaver.add_result((easy_iv, get_iv),
                             (I_source.current, I))
        
mw_source.status('OFF')
I_source.current(0)
# Out:
# Starting experimental run with id: 51.
#   0%|          | 0/201 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]

# %% [markdown]
# <h4 style="color:#4697E8";>Adwin ramp statistics</h4>

# %%
ad.input_mask(0b11)
ad.output_mask(0b11)
ad.adwin_mode(0b0)
ad.clear_fifos()
ad.go_to_zero()
VT = 2
offset = 3
ramp_param = ADwin_averagedRamp("avg_ramp_statistics2",
                        ad, 
                        period=0.2, 
                        n_pts=501,
                        N_ramp=11,
                        Vs_high=np.array([VT+offset, -VT+offset]),
                        Vs_low=np.array([-VT+offset, VT+offset]),
                        progress= False)

easy_iv = ADwin_IV(ramp_param.name+'_iv', ramp_param,
                  voltage_input=2,
                  current_input=1,
                  voltage_divider_value=1e3,
                  current_coefficient=1e9)

tokenParameter = Parameter(name='ramp_number2',
                    label='Number of the ramp',
                    unit= '',
                    vals=validators.Numbers(0,1e5),
                    get_cmd=None,
                    set_cmd=None
                   )


experiment_name = 'iv_curves'
exp = load_or_create_experiment(experiment_name=experiment_name, sample_name=sample_name)

# %%
f = 4.04e9
p = -5.1

Ib = 0.0
N_avg_ramps = 10000


meas = qc.Measurement(exp=exp, station=STATION, name='iv_mwon_f404p-55_stat_sweep')

mw_source.frequency(f)
mw_source.power(p)
mw_source.status('ON')

I_source.current(Ib)


# logging

meas.register_parameter(tokenParameter)
meas.register_parameter(easy_iv, setpoints=[tokenParameter])
meas.write_period = 10

# measurement
with meas.run() as datasaver:
    for k in tqdm.tqdm(range(N_avg_ramps)):
        # I_source.current(I)
        get_iv = easy_iv() 

        datasaver.add_result((easy_iv, get_iv),
                             (tokenParameter, k))
        
mw_source.status('OFF')
I_source.current(0)
# Out:
# Starting experimental run with id: 4.
#   0%|          | 0/10000 [00:00<?, ?it/s]

# %% [markdown]
# <h3  style="color:#4697E8";>Spectrum analyser</h3>

# %% [markdown]
# <h4 style="color:#4697E8";>Spectrum analyser vs DC bias (searching sidebands)</h4>

# %%
experiment_name = 'trace_spectrum_analyser'
measurement_name = '1dtrace_sa'
exp = load_or_create_experiment(experiment_name=experiment_name, sample_name=sample_name)

meas = qc.Measurement(exp=exp, station=STATION, name=measurement_name)


# spectrum analyser setup
spectrum_analyser.center_freq(4.113e9)
spectrum_analyser.span(4e9)
spectrum_analyser.n_points(10001)
spectrum_analyser.res_BW(1e4)

spectrum_analyser.average_type('pow')
spectrum_analyser.averages(20)

# adwin setup
ad.input_mask(0b1)
ad.output_mask(0b11)
ad.adwin_mode(0b0)
ad.clear_fifos()
ad.go_to_zero()
VT = 7
I = 5e-3
offset = 2.67

# mw source
mw_source.power(-30)
mw_source.frequency(4.113e9)

I_source.current(I)
ad_Vs = np.linspace(-VT+offset,VT+offset, num=1000)
background = spectrum_analyser.spectrum()

meas.register_parameter(adVbias)
meas.register_parameter(spectrum_analyser.spectrum, setpoints=[adVbias])

mw_source.status('ON')

with meas.run() as datasaver :
    for v_ad in tqdm.tqdm(ad_Vs):
        adwin_target = np.array([v_ad, v_ad])
        ad.outputs(adwin_target)
        ad.launch_measurement()
        ad.clear_fifos()
        
        trace = spectrum_analyser.spectrum() - background
        datasaver.add_result((adVbias, v_ad),
                             (spectrum_analyser.spectrum, trace))

ad.clear_fifos()
ad.go_to_zero()
mw_source.status('OFF')

I_source.current(0.0)
# Out:
# Starting experimental run with id: 9.
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %% [markdown]
# <h4 style="color:#4697E8";>Signal hound</h4>

# %%
experiment_name = 'tone_sidebands'
measurement_name = 'mw_tone_p-5dbm_f4.04ghz_modon'
exp = load_or_create_experiment(experiment_name=experiment_name, sample_name=sample_name)

# %%
f = 4.04e9

sh.frequency(f + 100)
sh.span(500) # rbw?
sh.rbw(30)
sh.vbw(30)
sh.avg(10)


#Modulation 
mw_source.power(-5)
mw_source.frequency(f)
mw_source.status('ON')

# lock-in source parameters
li.frequency(100.1)  # Hz
li.amplitude(0.4) # V

sh.configure()
do0d(sh.trace)
# Out:
# Starting experimental run with id: 11. Using 'qcodes.utils.dataset.doNd.do0d'
# (results #11@D:\QMET\azog_c1\20220203_ncr_lock-in_v1.db
#  ------------------------------------------------------
#  signal_hound_frequency - array
#  signal_hound_trace - array,
#  [<AxesSubplot:title={'center':'Run #11, Experiment tone_sidebands (azog_c1)'}, xlabel='Frequency (GHz)', ylabel='Magnitude (dBm)'>],
#  [None])

# %% [markdown]
# <h3 style="color:#4697E8";>Lock-in amplifier</h3>

# %% [markdown]
# <h4 style="color:#4697E8";>IV curve</h4>

# %%
experiment_name = 'dIdV'
measurement_name = 'dIdV_pm3V_f211_tau0.1s_0flux_rampdown'
exp = load_or_create_experiment(experiment_name=experiment_name, sample_name=sample_name)

# %%
frequency = 211

# first output used to modulate the signal sent to the sample
afg.voltage_amplitude1(0.01)
afg.voltage_offset1(0)
afg.impedance_output1(10e3)

# second output used to trigger the lock-in
afg.voltage_amplitude2(1)
afg.voltage_offset2(0)

afg.freq_cw1(frequency)
afg.freq_cw2(frequency)

# synch the two
afg.synchronize_phase(0)

# %%
tau = 100e-3
vmin = -3
vmax = 3
n_points = 2001
I_source.current(0.0)

li.time_constant(tau)  # s

afg.state_output1('ON')
afg.state_output2('ON')
do1d(afg.voltage_offset1, vmax, vmin, n_points, tau, li.R)
afg.state_output1('OFF')
afg.state_output2('OFF')
# Out:
# Starting experimental run with id: 4. Using 'qcodes.utils.dataset.doNd.do1d'
#   0%|          | 0/2001 [00:00<?, ?it/s]

# %% [markdown]
# <h4 style="color:#4697E8";>IV curve and flux</h4>

# %%
experiment_name = 'dIdV_flux'
measurement_name = 'dIdV_flux_pm3V_f211_tau0.1s_rampup'
exp = load_or_create_experiment(experiment_name=experiment_name, sample_name=sample_name)

# %%
# measurement frequency
frequency = 211

# first output used to modulate the signal sent to the sample
afg.voltage_amplitude1(0.01)
afg.voltage_offset1(0)
afg.impedance_output1(10e3)

# second output used to trigger the lock-in
afg.voltage_amplitude2(1)
afg.voltage_offset2(0)

afg.freq_cw1(frequency)
afg.freq_cw2(frequency)

# synch the two
afg.synchronize_phase(0)

# %%
tau = 10e-3
vmin = -3
vmax = 3
n_points = 501

phimin = -30e-3
phimax = 30e-3
Ipoints = 101
I_source.current(0.0)

li.time_constant(tau)  # s

afg.state_output1('ON')
afg.state_output2('ON')

do2d(I_source.current, phimin, phimax, Ipoints, 0.01, afg.voltage_offset1, vmin, vmax, n_points, tau, li.R)

afg.state_output1('OFF')
afg.state_output2('OFF')
I_source.current(0.0)
# Out:
# Starting experimental run with id: 8. Using 'qcodes.utils.dataset.doNd.do2d'
#   0%|          | 0/101 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]

# %% [markdown]
# <h4 style="color:#4697E8";>Microwave tone modulation</h4>

# %%
experiment_name = 'dIdP'
measurement_name = 'dIdp_adV2.8V_f11_tau30s_mwf4.04'
exp = load_or_create_experiment(experiment_name=experiment_name, sample_name=sample_name)

# %%
# lock-in parameters
# the tau is long and the frequency is low because the measurement suffers from 
# low-frequency instability, so to average them out we need to make a looong run.

tau = 30

li.frequency(11)  # Hz
li.amplitude(0.4) # V
li.time_constant(tau)  # s

# %%
# fixed voltage set with the adwin
v_ad = 2.8

# frequency and power of the microwave tone
f = 4.04e9
# p = -5.1
pmin = -8
pmax = 0
n_power = 1501
mw_source.frequency(f)
# mw_source.power(p)

# turn on the adwin voltage
adwin_target = np.array([v_ad, v_ad])
ad.outputs(adwin_target)
ad.launch_measurement()

mw_source.status('ON')
do1d(mw_source.power, pmin, pmax, n_power, tau, li.R)
mw_source.status('OFF')

ad.clear_fifos()
ad.go_to_zero()
# Out:
# Starting experimental run with id: 13. Using 'qcodes.utils.dataset.doNd.do1d'
#   0%|          | 0/1501 [00:00<?, ?it/s]

# %% [markdown]
# <h3  style="color:#4697E8";>Current biasing with a $100\,\mathrm{M\Omega}$ resistor</h3>

# %%
experiment_name = 'VI_curves'
measurement_name = 'VI_base'
exp = load_or_create_experiment(experiment_name=experiment_name, sample_name=sample_name)

# %%
ad.input_mask(0b11)
ad.output_mask(0b11)
ad.adwin_mode(0b0)
ad.clear_fifos()
ad.go_to_zero()

VT = 0.2
offset = 0.00
ramp_param = ADwin_averagedRamp("current_bias_small_IC_10syy", 
                        ad, 
                        period=10,
                        n_pts=10001,
                        N_ramp=1,
                        Vs_high=np.array([VT+offset, VT+offset]),
                        Vs_low=np.array([-VT+offset, -VT+offset]),
                        progress= False)

easy_iv = ADwin_VI(ramp_param.name+'vi', ramp_param,
                  voltage_input=2,
                  current_input=1,
                  current_divider_value=1e8,
                  voltage_coefficient=1e2) # actually voltage coefficient here

# %% [markdown]
# <h4 style="color:#4697E8";>VI versus flux</h4>

# %%
meas = qc.Measurement(exp=exp, station=STATION, name='vi_fluxsweep')

# flux
currents = np.linspace(-10e-3,  10e-3, num=101)

# logging
meas.register_parameter(I_source.current)
meas.register_parameter(easy_iv, setpoints=[I_source.current])
meas.write_period = 10

# measurement
with meas.run() as datasaver:
    for I in tqdm.tqdm(currents):
        I_source.current(I)
        get_iv = easy_iv() 

        datasaver.add_result((easy_iv, get_iv),
                             (I_source.current, I))
        
I_source.current(0)
# Out:
# Starting experimental run with id: 2.
#   0%|          | 0/101 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]

# %% [markdown]
# <h4 style="color:#4697E8";>VNA versus current bias</h4>

# %%
experiment_name = 's21'
measurement_name = 's21_vs_current_dc'
exp = load_or_create_experiment(experiment_name=experiment_name, sample_name=sample_name)

# %%
adVbias = Parameter(name='adwin_output1',
                    label='Adwin output voltage converted to current',
                    unit= 'A',
                    vals=validators.Numbers(-10,10),
                    get_cmd=None,
                    set_cmd=None
                   )

# %%
meas = qc.Measurement(exp=exp, station=STATION, name='vna_trace_vs_current_bias_4.04GHzmode' )

# mw
f = 4.04e9
p = -5.5
# mw_source.frequency(f)
# mw_source.power(p)

s21.center(f)
s21.span(5e8)
s21.npts(2001)
s21.bandwidth(1e3)
s21.averaging_enabled(True)
s21.avg(1)
# 30dB of attenuation added at the output
s21.power(0)

# s21.set_electrical_delay_auto()
s21.average_clear()

ad.input_mask(0b1)
ad.output_mask(0b11)
ad.adwin_mode(0b0)
ad.clear_fifos()
ad.go_to_zero()

VT = 0.01
I = 0e-3
offset = 0.05
# I_source.current(I)
ad_Vs = np.linspace(offset-VT,VT+offset, num=201)

meas.register_parameter(adVbias)
meas.register_parameter(s21.trace_mag_phase, setpoints=[adVbias])

vna.rf_on()

with meas.run() as datasaver :
    for v_ad in tqdm.tqdm(ad_Vs):
        adwin_target = np.array([v_ad, v_ad])
        ad.outputs(adwin_target)
        ad.launch_measurement()
        ad.clear_fifos()
        
        trace = s21.trace_mag_phase()
        datasaver.add_result((adVbias, v_ad/1e8),
                             (s21.trace_mag_phase, trace))

vna.rf_off()
ad.clear_fifos()
ad.go_to_zero()
# I_source.current(0.0)

# res[0].captured_run_id
# Out:
# Starting experimental run with id: 5.
#   0%|          | 0/201 [00:00<?, ?it/s]

# %% [markdown]
# <h2 style="color:#1C3C5C";>Data preview</h2>
# Using the experiments widget to look at all the measurements in the database, or filter them by experiment.

# %%
#experiments = qc.experiments()                       # define the experiments
#data_sets = experiments[1].data_sets()               # select only one experiment
#experiments_widget(data_sets=data_sets)              # start the widget on the selected experiment

experiments_widget(db=qc.config.core.db_location)  # start the widget on the whole database
# Out:
# VBox(children=(HTML(value='<h1>QCoDeS experiments widget</h1>'), Tab(children=(Output(),), _titles={'0': 'Info…
